# %%
#imports
import pandas as pd

# %%
import json
with open('/Users/thoma/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# import the YelpAPI Class
from yelpapi import YelpAPI
# Create an instance with your key
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
help(yelp_api.search_query)
# Out:
# Help on method search_query in module yelpapi.yelpapi:
#
# search_query(**kwargs) method of yelpapi.yelpapi.YelpAPI instance
#     Query the Yelp Search API.
#
#     documentation: https://www.yelp.com/developers/documentation/v3/business_search
#
#     required parameters:
#         * one of either:
#             * location - text specifying a location to search for
#             * latitude and longitude

# %%
# use our yelp_api variable's search_query method to perform our API call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes')
print(type(search_results))
search_results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
search_results['total']
# Out:
# 441

# %%
biz = pd.DataFrame(search_results['businesses'])
biz.head(2)
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
#
#                          name  \
# 0           Faidley's Seafood
# 1  Thames Street Oyster House
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1229
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2836
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
#
#                                        coordinates transactions price  \
# 0  {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
# 1   {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
#
#                                             location         phone  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 1  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
#
#     display_phone     distance
# 0  (410) 727-4898  1349.560720
# 1  (443) 449-7726  2090.712792

# %%
## total number of matching businesses
search_results['total']
# Out:
# 441

# %%
## how many businesses in our results
len(search_results['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
search_results = yelp_api.search_query(location='Baltimore, MD,21202',
                                       term='Crab Cakes',
                                       offset = 20)

# %%
biz20 = pd.DataFrame(search_results['businesses'])
biz20.head(2)
# Out:
#                        id                             alias  \
# 0  VLGdENTqjFJuCjg1SbW7_g        nicks-fish-house-baltimore
# 1  TPQmNAM2g1vmm2xCfhyEJw  pratt-street-ale-house-baltimore
#
#                      name                                          image_url  \
# 0        Nicks Fish House  https://s3-media3.fl.yelpcdn.com/bphoto/xMvMJ9...
# 1  Pratt Street Ale House  https://s3-media4.fl.yelpcdn.com/bphoto/DA0K3G...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/nicks-fish-house-balt...           927
# 1      False  https://www.yelp.com/biz/pratt-street-ale-hous...           837
#
#                                           categories  rating  \
# 0         [{'alias': 'seafood', 'title': 'Seafood'}]     4.0
# 1  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     3.5
#
#                                          coordinates        transactions  \
# 0     {'latitude': 39.26036, 'longitude': -76.61421}          [delivery]
# 1  {'latitude': 39.2865982055664, 'longitude': -7...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '2600 Insulator Dr', 'address2': ...  +14103474123
# 1    $$  {'address1': '206 W Pratt St', 'address2': '',...  +14102448900
#
#     display_phone     distance
# 0  (410) 347-4123  3984.496569
# 1  (410) 244-8900  1403.278532

# %%
## concatenate the previous results and new results. 
businesses = pd.concat([biz, biz20],
                      ignore_index=True)
display(businesses.head(3), businesses.tail(3))
# Out:
#                        id                                 alias  \
# 0  D9A33FM394q99o4QtK5YwA          faidleys-seafood-baltimore-3
# 1  ieS_5zqxDHcWMCm8BKUYbg  thames-street-oyster-house-baltimore
# 2  u65W69AhbjUlvJJBkEhGNQ        miss-shirleys-cafe-baltimore-9
#
#                          name  \
# 0           Faidley's Seafood
# 1  Thames Street Oyster House
# 2         Miss Shirley's Cafe
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/8j3ynZ...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/9hGjo5...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/Guq6JM...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/faidleys-seafood-balt...          1229
# 1  https://www.yelp.com/biz/thames-street-oyster-...          2836
# 2  https://www.yelp.com/biz/miss-shirleys-cafe-ba...          3053
#
#                                           categories  rating  \
# 0  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 2  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
#
#                                          coordinates transactions price  \
# 0    {'latitude': 39.291696, 'longitude': -76.62224}   [delivery]    $$
# 1     {'latitude': 39.28214, 'longitude': -76.59162}   [delivery]   $$$
# 2  {'latitude': 39.2870995, 'longitude': -76.6053...   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '203 N Paca St', 'address2': '', ...  +14107274898
# 1  {'address1': '1728 Thames St', 'address2': '',...  +14434497726
# 2  {'address1': '750 E Pratt St', 'address2': '',...  +14105285373
#
#     display_phone     distance
# 0  (410) 727-4898  1349.560720
# 1  (443) 449-7726  2090.712792
# 2  (410) 528-5373  1028.736468
#                         id                                  alias  \
# 37  0HAy_fw3WrsiG_5lRVObTw     captain-james-crab-house-baltimore
# 38  yllFleLLvGVm9dZ-dRFZHg                 papi-cuisine-baltimore
# 39  19NqOlADe8wHXWtx5sWRtQ  busboys-and-poets-baltimore-baltimore
#
#                              name  \
# 37       Captain James Crab House
# 38                   Papi Cuisine
# 39  Busboys and Poets - Baltimore
#
#                                             image_url  is_closed  \
# 37  https://s3-media4.fl.yelpcdn.com/bphoto/B3MLVa...      False
# 38  https://s3-media2.fl.yelpcdn.com/bphoto/uBoDyK...      False
# 39  https://s3-media2.fl.yelpcdn.com/bphoto/jSYlOA...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/captain-james-crab-ho...           401
# 38  https://www.yelp.com/biz/papi-cuisine-baltimor...           436
# 39  https://www.yelp.com/biz/busboys-and-poets-bal...           164
#
#                                            categories  rating  \
# 37  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     3.5
# 38  [{'alias': 'cocktailbars', 'title': 'Cocktail ...     4.0
# 39  [{'alias': 'newamerican', 'title': 'American (...     4.0
#
#                                           coordinates        transactions  \
# 37     {'latitude': 39.28346, 'longitude': -76.58633}          [delivery]
# 38  {'latitude': 39.26920460905755, 'longitude': -...          [delivery]
# 39  {'latitude': 39.32772376459962, 'longitude': -...  [pickup, delivery]
#
#    price                                           location         phone  \
# 37    $$  {'address1': '2121 Aliceanna St', 'address2': ...  +14103278600
# 38   $$$  {'address1': '2 E Wells St', 'address2': 'Ste ...  +16672051838
# 39    $$  {'address1': '3224 St Paul St', 'address2': No...  +14104977114
#
#      display_phone     distance
# 37  (410) 327-8600  2343.033653
# 38  (667) 205-1838  3026.776496
# 39  (410) 497-7114  3584.688707
